# %%
import pandas as pd

# %%
df = pd.read_csv("data/processed_data.csv")

# %%
time_steps = df[1].unique()

# %%
for t in time_steps:
    temp_df = df[df[1] == t]
    print(f"Processing time step {t}, size={len(temp_df)}")
